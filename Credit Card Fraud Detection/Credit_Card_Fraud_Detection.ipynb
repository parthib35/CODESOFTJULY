# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
df = pd.read_csv ('/content/drive/MyDrive/creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
corrmat = df.corr(method = "spearman")
plt.figure(figsize=(18,15))
#plot heat map
g=sns.heatmap(corrmat,annot=True)

# %%
sns.countplot(data=df,x='Class')
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
X = df.drop(["Class"], axis = 1)
y = df["Class"]

# %%
rs = RandomUnderSampler(random_state=0)
X_res, y_res = rs.fit_resample(X, y)
print('original dataset shape %s' %Counter(y))
print('After oversampling dataset shape %s' %Counter(y_res))
# Out:
# original dataset shape Counter({0: 284315, 1: 492})
# After oversampling dataset shape Counter({0: 492, 1: 492})

# %%
x_train, x_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (787, 30) (787,)
# (197, 30) (197,)

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred1 = rf.predict(x_test)
score = accuracy_score(y_test, pred1)
cn = confusion_matrix(y_test, pred1)
ax = plt.subplot()
sns.heatmap(cn / np.sum(cn), annot = True, ax=ax)
plt.plot()
print('Acccuracy: ',score)
# Out:
# Acccuracy:  0.9644670050761421

# %%
print(classification_report(y_test,pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       104
#            1       0.98      0.95      0.96        93
#
#     accuracy                           0.96       197
#    macro avg       0.97      0.96      0.96       197
# weighted avg       0.96      0.96      0.96       197

# %%
m=mean_squared_error(y_test,pred1)
root_mean_squared_error = sqrt(m)
N=mean_absolute_error(y_test,pred1)
R=r2_score(y_test, pred1)
print('R2_Score:',R)
print('Mean_squared_error:',m)
print('root_mean_squared_error:',root_mean_squared_error)
print('Mean_absolute_error',N)
# Out:
# R2_Score: 0.8574234904880067
# Mean_squared_error: 0.03553299492385787
# root_mean_squared_error: 0.18850197591499637
# Mean_absolute_error 0.03553299492385787

# %%
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
pred2 = logreg.predict(x_test)
score = accuracy_score(y_test, pred2)
cn = confusion_matrix(y_test, pred2)
ax = plt.subplot()
sns.heatmap(cn / np.sum(cn), annot = True, linewidths=.15, ax=ax)
plt.plot()
print('Acccuracy: ',score)
# Out:
# Acccuracy:  0.9543147208121827

# %%
print(classification_report(y_test,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       104
#            1       0.97      0.94      0.95        93
#
#     accuracy                           0.95       197
#    macro avg       0.96      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %%
m=mean_squared_error(y_test,pred2)
root_mean_squared_error = sqrt(m)
N=mean_absolute_error(y_test,pred2)
MSE = np.square(np.subtract(y_test,pred2)).mean()
R=r2_score(y_test, pred2)
print('R2_Score:',R)
print('Mean_squared_error:',m)
print('root_mean_squared_error:',root_mean_squared_error)
print('Mean_absolute_error',N)
# Out:
# R2_Score: 0.8166873449131514
# Mean_squared_error: 0.04568527918781726
# root_mean_squared_error: 0.21374114996372892
# Mean_absolute_error 0.04568527918781726
